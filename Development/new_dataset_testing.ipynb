# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import xarray as xr
from glob import glob
import os
from netCDF4 import Dataset
import pandas as pd
from datetime import datetime, date, timedelta
from pathlib import Path
import scipy
import scipy.ndimage
from mpl_toolkits.axes_grid1 import ImageGrid
import math
import cc3d

from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
t=3

shell_input_dir = Path("/mnt/stor-pool-01/projects/heus/rico/doubledump")
ds_e = xr.open_dataset(shell_input_dir / "netE.nc", decode_times=False)
ds_ql =xr.open_dataset(shell_input_dir / "ql.nc", decode_times=False)

e_slice = ds_e.isel(time=t)
ql_slice = ds_ql.isel(time=t)

# %%
e_slice
# Out:
# <xarray.Dataset> Size: 333MB
# Dimensions:     (x: 512, y: 512, z: 159)
# Coordinates:
#     time        float32 4B 1.44e+04
#   * x           (x) float32 2kB 25.0 75.0 125.0 ... 2.552e+04 2.558e+04
#   * y           (y) float32 2kB 25.0 75.0 125.0 ... 2.552e+04 2.558e+04
#   * z           (z) float32 636B 10.0 30.0 52.0 ... 1.146e+04 1.214e+04
# Data variables:
#     netE_ql     (z, y, x) float32 167MB ...
#     netE_shell  (z, y, x) float32 167MB ...

# %%
ql_slice
# Out:
# <xarray.Dataset> Size: 167MB
# Dimensions:  (z: 159, y: 512, x: 512)
# Coordinates:
#     time     float32 4B 7.1e+03
#   * z        (z) float32 636B 10.0 30.0 52.0 ... 1.083e+04 1.146e+04 1.214e+04
#   * y        (y) float32 2kB 25.0 75.0 125.0 ... 2.548e+04 2.552e+04 2.558e+04
#   * x        (x) float32 2kB 25.0 75.0 125.0 ... 2.548e+04 2.552e+04 2.558e+04
# Data variables:
#     ql       (z, y, x) float32 167MB ...
