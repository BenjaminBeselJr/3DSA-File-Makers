# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import xarray as xr
from glob import glob
import os
from netCDF4 import Dataset
import pandas as pd
from datetime import datetime, date, timedelta
from pathlib import Path
import scipy
import scipy.ndimage
from mpl_toolkits.axes_grid1 import ImageGrid
import math
import cc3d

from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
t=3

shell_input_dir = Path("/mnt/stor-pool-01/projects/heus/rico/doubledump")
ds_e = xr.open_dataset(shell_input_dir / "netE.nc", decode_times=False)
ds_ql =xr.open_dataset(shell_input_dir / "ql.nc", decode_times=False)

e_slice = ds_e.isel(time=t)
ql_slice = ds_ql.isel(time=t)

# %%
e_slice
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:     (x: 1536, y: 1536, z: 200)
# Coordinates:
#     time        float32 4B 7.2e+03
#   * x           (x) float32 6kB 12.5 37.5 62.5 ... 3.834e+04 3.836e+04 3.839e+04
#   * y           (y) float32 6kB 12.5 37.5 62.5 ... 3.834e+04 3.836e+04 3.839e+04
#   * z           (z) float32 800B 12.5 37.5 62.5 ... 4.962e+03 4.988e+03
# Data variables:
#     netE_ql     (z, y, x) float32 2GB ...
#     netE_shell  (z, y, x) float32 2GB ...

# %%
ql_slice
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:  (z: 200, y: 1536, x: 1536)
# Coordinates:
#     time     float32 4B 3.597e+03
#   * z        (z) float32 800B 12.5 37.5 62.5 ... 4.938e+03 4.962e+03 4.988e+03
#   * y        (y) float32 6kB 12.5 37.5 62.5 ... 3.834e+04 3.836e+04 3.839e+04
#   * x        (x) float32 6kB 12.5 37.5 62.5 ... 3.834e+04 3.836e+04 3.839e+04
# Data variables:
#     ql       (z, y, x) float32 2GB ...
